# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %% [markdown]
# ## Datasets references:
# ### [1] https://www.kaggle.com/datasets/nagwaelaraby/arabic-braille-characters
# #### 31 Classes were taken from this dataset.
#
# ### [2] https://www.kaggle.com/datasets/shemescobal/braille-dataset-2/data
# #### The remaining 2 classes were taken from this dataset
# #### (ز, ئ)
# ### Total images are 3,267
# #### 99 image per class

# %%
dataset_dir = "Arabic Braille"

image_size = (50, 50)
batch_size = 32  #Default batch size
validation_split = 0.2

# Load the dataset (without splitting)
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    image_size=image_size,
    batch_size=batch_size,  # Specify the batch size
    label_mode='int',
    shuffle=False  # Disable shuffling
)

# Load the training dataset (80% of data)
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=validation_split,  # Use 20% for validation
    subset="training",  # Specify the subset for training
    seed=1234,  # Ensure shuffling is consistent (No overlap)
    image_size=image_size,
    batch_size=batch_size  # Specify the batch size
)

# Load the validation dataset (20% of data)
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=validation_split,  # Use 20% for validation
    subset="validation",  # Specify the subset for validation
    seed=1234,  # Ensure shuffling is consistent (No overlap)
    image_size=image_size,
    batch_size=batch_size  # Specify the batch size
)
# Out:
# Found 3267 files belonging to 33 classes.
# Found 3267 files belonging to 33 classes.
# Using 2614 files for training.
# Found 3267 files belonging to 33 classes.
# Using 653 files for validation.

# %%
# Get one batch of data from train_dataset
for images, labels in train_dataset.take(1):
    print(f"Images shape: {images.shape}")
    print(f"Labels shape: {labels.shape}")
# Out:
# Images shape: (32, 50, 50, 3)
# Labels shape: (32,)

# %%
class_names = train_dataset.class_names
print(class_names) 
print(len(class_names))
# Out:
# ['آ', 'أ', 'ؤ', 'ئ', 'ا', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ك', 'ل', 'م', 'ن', 'ه', 'و', 'ى', 'ي']
# 33

# %%
# Create a figure with subplots
plt.figure(figsize=(20, 15))

# Iterate over each class
for class_index in range(len(class_names)):
    # Filter the dataset for images from the current class and take the first image
    filtered_dataset = dataset.filter(lambda x, y: tf.math.equal(y[0], class_index)).take(1)

    # Get the first image and label from the filtered dataset
    for image, label in filtered_dataset:
        # Display the image
        plt.subplot(len(class_names) // 6 + 1, 6, class_index + 1) 
        plt.imshow(image[0].numpy().astype("uint8"))
        plt.title(f"Index: {class_index}, Class: {class_names[class_index]}")
        plt.axis("off")

# Show the plot
plt.show()

# %%
# Function to normalize the images
def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    return image, label

# Apply normalization to the datasets
train_dataset = train_dataset.map(normalize)
validation_dataset = validation_dataset.map(normalize)

# %%
# Define the CNN model with larger kernel sizes
model = models.Sequential([
    # First Convolutional Layer with larger kernel
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(50, 50, 3)),  # Changed to 5x5
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Second Convolutional Layer with larger kernel
    layers.Conv2D(64, (3, 3), activation='relu'),  # Changed to 5x5
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Third Convolutional Layer with larger kernel
    layers.Conv2D(128, (3, 3), activation='relu'),  # Changed to 5x5
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Flatten the output to feed into a dense layer
    layers.Flatten(),

    # Fully Connected Dense Layer
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),

    # Output layer for classification
    layers.Dense(len(class_names), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # or 'categorical_crossentropy'
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 32)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 33)                4257
#
# =================================================================
# Total params: 359,777
# Trainable params: 359,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=20
)
# Out:
# Epoch 1/20
# 82/82 [==============================] - 2s 21ms/step - loss: 3.5048 - accuracy: 0.0283 - val_loss: 3.4963 - val_accuracy: 0.0368
# Epoch 2/20
# 82/82 [==============================] - 2s 19ms/step - loss: 3.4928 - accuracy: 0.0394 - val_loss: 3.4813 - val_accuracy: 0.0368
# Epoch 3/20
# 82/82 [==============================] - 2s 20ms/step - loss: 3.1611 - accuracy: 0.1526 - val_loss: 2.3068 - val_accuracy: 0.4165
# Epoch 4/20
# 82/82 [==============================] - 2s 21ms/step - loss: 2.0059 - accuracy: 0.4461 - val_loss: 1.3649 - val_accuracy: 0.6401
# Epoch 5/20
# 82/82 [==============================] - 2s 20ms/step - loss: 1.4710 - accuracy: 0.5838 - val_loss: 0.9792 - val_accuracy: 0.7259
# Epoch 6/20
# 82/82 [==============================] - 2s 19ms/step - loss: 1.1445 - accuracy: 0.6611 - val_loss: 0.7909 - val_accuracy: 0.8086
# Epoch 7/20
# 82/82 [==============================] - 2s 19ms/step - loss: 0.9722 - accuracy: 0.7142 - val_loss: 0.6802 - val_accuracy: 0.8254
# Epoch 8/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.7751 - accuracy: 0.7640 - val_loss: 0.5891 - val_accuracy: 0.8652
# Epoch 9/20
# 82/82 [==============================] - 2s 19ms/step - loss: 0.6794 - accuracy: 0.7865 - val_loss: 0.5023 - val_accuracy: 0.8790
# Epoch 10/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.6124 - accuracy: 0.8137 - val_loss: 0.5541 - val_accuracy: 0.8652
# Epoch 11/20
# 82/82 [==============================] - 2s 19ms/step - loss: 0.5528 - accuracy: 0.8282 - val_loss: 0.5254 - val_accuracy: 0.8668
# Epoch 12/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.4777 - accuracy: 0.8485 - val_loss: 0.4326 - val_accuracy: 0.8882
# Epoch 13/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.4655 - accuracy: 0.8516 - val_loss: 0.4159 - val_accuracy: 0.8974
# Epoch 14/20
# 82/82 [==============================] - 2s 18ms/step - loss: 0.3980 - accuracy: 0.8856 - val_loss: 0.4142 - val_accuracy: 0.8959
# Epoch 15/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.3817 - accuracy: 0.8803 - val_loss: 0.4385 - val_accuracy: 0.8928
# Epoch 16/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.3551 - accuracy: 0.8864 - val_loss: 0.4015 - val_accuracy: 0.8959
# Epoch 17/20
# 82/82 [==============================] - 2s 21ms/step - loss: 0.3251 - accuracy: 0.8948 - val_loss: 0.3941 - val_accuracy: 0.9066
# Epoch 18/20
# 82/82 [==============================] - 2s 20ms/step - loss: 0.3386 - accuracy: 0.8990 - val_loss: 0.3882 - val_accuracy: 0.9051
# Epoch 19/20
# 82/82 [==============================] - 2s 19ms/step - loss: 0.3066 - accuracy: 0.9070 - val_loss: 0.3833 - val_accuracy: 0.9051
# Epoch 20/20
# 82/82 [==============================] - 2s 22ms/step - loss: 0.3017 - accuracy: 0.9109 - val_loss: 0.3656 - val_accuracy: 0.9142

# %%
print(f"Accuracy: {history.history['val_accuracy'][-1]:.2f}")
# Out:
# Accuracy: 0.91

# %%
# Load a batch of images for prediction
for images, labels in validation_dataset.take(1):  # Take a single batch from the validation dataset
    predictions = model.predict(images)  # Predict on the batch
    predicted_labels = np.argmax(predictions, axis=1)  # Get the predicted class for each image

    # Plot a few sample images with their predicted labels
    plt.figure(figsize=(10, 10))
    
    for i in range(9):  # Display 9 images
        plt.subplot(3, 3, i+1)
        
        plt.imshow(images[i].numpy())
        
        plt.title(f"Pred: {class_names[predicted_labels[i]]}, True: {class_names[labels[i].numpy()]}")  # Show predicted and true label
        plt.axis("off")
    
    plt.show()
# Out:
# 1/1 [==============================] - 0s 92ms/step

# %%
hist = history.history
x_arr = np.arange(len(hist['loss']))+1
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1)
ax.plot(x_arr,hist['loss'],'--o',label='Train Loss')
ax.plot(x_arr,hist['val_loss'],'--c',label='Validation Loss')
ax.set_xlabel('Epoch',size=15)
ax.set_ylabel('Loss',size=15)
ax.legend(fontsize=15)
ax = fig.add_subplot(1,2,2)
ax.plot(x_arr,hist['accuracy'],'--o',label='Train Accuracy')
ax.plot(x_arr,hist['val_accuracy'],'--c',label='Validation Accuracy')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch',size=15)
ax.set_ylabel('Accuracy',size=15)
plt.show()

# %%
# Load true labels and predicted labels from the validation dataset
true_labels = []
predicted_labels = []

# Loop through the validation dataset to get true labels and predictions
for images, labels in validation_dataset:
    predictions = model.predict(images)  # Predict on the batch
    predicted_labels_batch = np.argmax(predictions, axis=1)  # Get predicted class
    predicted_labels.extend(predicted_labels_batch)  # Collect predicted labels
    true_labels.extend(labels.numpy())  # Collect true labels

# Convert lists to numpy arrays for confusion matrix
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print the classification report
print(classification_report(true_labels, predicted_labels))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 86ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        20
#            1       0.89      0.84      0.86        19
#            2       1.00      0.86      0.92        14
#            3       1.00      1.00      1.00        16
#            4       0.90      0.90      0.90        20
#            5       0.94      0.94      0.94        17
#            6       0.79      0.83      0.81        23
#            7       0.86      0.96      0.91        25
#            8       0.81      0.94      0.87        18
#            9       1.00      0.78      0.88        18
#           10       1.00      0.90      0.95        20
#           11       0.75      1.00      0.86        15
#           12       0.92      0.96      0.94        24
#           13       1.00      0.90      0.95        21
#           14       0.94      1.00      0.97        16
#           15       0.78      0.95      0.86        19
#           16       1.00      0.80      0.89        20
#           17       0.91      1.00      0.95        21
#           18       1.00      0.92      0.96        24
#           19       1.00      0.94      0.97        18
#           20       0.94      0.94      0.94        17
#           21       0.96      0.92      0.94        25
#           22       0.93      0.93      0.93        14
#           23       0.94      0.85      0.89        20
#           24       0.76      0.94      0.84        17
#           25       0.93      0.93      0.93        27
#           26       1.00      0.84      0.91        25
#           27       0.78      0.82      0.80        17
#           28       1.00      0.90      0.95        20
#           29       1.00      0.90      0.95        20
#           30       0.91      1.00      0.95        20
#           31       0.86      1.00      0.92        18
#           32       0.88      0.88      0.88        25
#
#     accuracy                           0.91       653
#    macro avg       0.92      0.92      0.91       653
# weighted avg       0.92      0.91      0.92       653

# %%
# After training your model, save it to a file
model.save('models/Braille-v2-k3.h5')
